# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Read raw data

# %%
usda_df = pd.read_csv('../../raw_data/comprehensive_foods_usda.csv')
healthyFoods_df= pd.read_csv('../../raw_data/healthy_foods_database.csv')
allergens_df = pd.read_csv("../../raw_data/foods_health_scores_allergens.csv", encoding="utf-8")

# %% [markdown]
# # Exploration

# %%
print(f"{'Dataset':<15} {'Rows':>8} {'Cols':>6}")
print("-" * 32)
print(f"{'USDA':<15} {usda_df.shape[0]:>8,} {usda_df.shape[1]:>6}")
print(f"{'HealthyFoods':<15} {healthyFoods_df.shape[0]:>8,} {healthyFoods_df.shape[1]:>6}")
print(f"{'Allergens':<15} {allergens_df.shape[0]:>8,} {allergens_df.shape[1]:>6}")
# Out:
# Dataset             Rows   Cols
# --------------------------------
# USDA              40,000     24
# HealthyFoods       9,028     10
# Allergens          4,997     24

# %%
print("-"*80)
print(" DATASET 1: USDA FOODS (Main Dataset)")
print("-"*80)
print(f"\nShape: {usda_df.shape}")
print(f"\nColumn Names:\n{usda_df.columns.tolist()}")
print(f"\nFirst 3 rows:")
display(usda_df.head(3))

print("\n" + "-"*80)
print(" DATASET 2: HEALTHY FOODS")
print("-"*80)
print(f"\nShape: {healthyFoods_df.shape}")
print(f"\nColumn Names:\n{healthyFoods_df.columns.tolist()}")
print(f"\nFirst 3 rows:")
display(healthyFoods_df.head(3))

print("\n" + "-"*80)
print(" DATASET 3: ALLERGENS FOCUSED")
print("-"*80)
print(f"\nShape: {allergens_df.shape}")
print(f"\nColumn Names:\n{allergens_df.columns.tolist()}")
display(allergens_df.head(3))

print("\n" + "-"*80)
print(" DATASET 3: ALLERGENS")
print("-"*80)
print(f"\nShape: {allergens_df.shape}")
print(f"\nColumn Names:\n{allergens_df.columns.tolist()}")
display(allergens_df.head(3))
# Out:
# --------------------------------------------------------------------------------
#  DATASET 1: USDA FOODS (Main Dataset)
# --------------------------------------------------------------------------------
#
# Shape: (40000, 24)
#
# Column Names:
# ['fdc_id', 'food_name', 'data_type', 'food_category', 'brand_owner', 'brand_name', 'ingredients', 'serving_size', 'serving_unit', 'household_serving', 'calories', 'carbs_g', 'calcium_mg', 'fat_g', 'protein_g', 'saturated_fat_g', 'vitamin_c_mg', 'fiber_g', 'iron_mg', 'sodium_mg', 'sugar_g', 'cholesterol_mg', 'health_score', 'food_type']
#
# First 3 rows:
#    fdc_id                           food_name  data_type  \
# 0  167782                        Abiyuch, raw  SR Legacy
# 1  171687                  Acerola juice, raw  SR Legacy
# 2  171686  Acerola, (west indian cherry), raw  SR Legacy
#
#              food_category brand_owner brand_name ingredients  serving_size  \
# ...

# %% [markdown]
# # Save to bronze_layer (as-is)

# %%
usda_df.to_csv("../data/bronze_layer/usda.csv", index=False)
healthyFoods_df.to_csv("../data/bronze_layer/healthyFoods.csv", index=False)
allergens_df.to_csv("../data/bronze_layer/allergens.csv", index=False)
